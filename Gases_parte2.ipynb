# %% [markdown]
# <a href="https://colab.research.google.com/github/RENZO140525/UNMSM_quimica_2023pc1/blob/main/Gases_parte2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gases (continuación)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Ejemplo 1: Graficar en barras el número de participaciones de los países en el mundial, según Wikipedia

# %%
url = 'https://es.wikipedia.org/wiki/Anexo:Estad%C3%ADsticas_de_la_Copa_Mundial_de_F%C3%BAtbol'
tablas = pd.read_html(url)

# %%
tablas[9].head(10)
# Out:
#     Año                                     Canción                 Artistas  \
# 0  1948    "Let It Snow! Let It Snow! Let It Snow!"            Frank Sinatra
# 1  1954                     "Rock Around the Clock"  Bill Haley & His Comets
# 2  1956                                 "Hound Dog"            Elvis Presley
# 3  1957                          "Jingle Bell Rock"              Bobby Helms
# 4  1958         "Rockin' Around the Christmas Tree"               Brenda Lee
# 5  1959              "Put Your Head on My Shoulder"                Paul Anka
# 6  1960                           "Wonderful World"                Sam Cooke
# 7  1961                "Can't Help Falling in Love"            Elvis Presley
# 8  1962                    "Bring It On Home to Me"                Sam Cooke
# 9  1963  "It's the Most Wonderful Time of the Year"            Andy Williams
#
#   Reproducciones (en millones)   Fecha de publicación   Ref.
# 0                          307                   1948  [69]​
# 1                           61                   1954  [70]​
# 2                          149    13 de julio de 1956  [71]​
# 3                          401        octubre de 1957  [72]​
# 4                          409                   1958  [73]​
# 5                          212                   1959  [74]​
# 6                          285    14 de abril de 1960    NaN
# 7                          430          Abril de 1961    NaN
# 8                          174      8 de mayo de 1962    NaN
# 9                          399  14 de octubre de 1963    NaN

# %%
plt.figure(figsize=(20,4))
plt.xticks(rotation=90)
plt.bar(tablas[9]['Selección'],tablas[9]['Apariciones'])
# Out:
# <BarContainer object of 78 artists>

# %% [markdown]
# Ejemplo 2: Hacer una gráfica de barras de las canciones más reproducidas en Spotify

# %%
pagina = 'https://es.wikipedia.org/wiki/Anexo:Canciones_m%C3%A1s_reproducidas_en_Spotify'
tablas = pd.read_html(pagina)

# %%
tablas[13]
# Out:
#                                   Álbum            Artista  \
# 0               Midnights (3am Edition)       Taylor Swift
# 1                   Certified Lover Boy              Drake
# 2   Nadie sabe lo que va a pasar mañana          Bad Bunny
# 3                      Un verano sin ti          Bad Bunny
# 4                              Scorpion              Drake
# 5          Speak Now (Taylor's Version)       Taylor Swift
# 6                      For All The Dogs              Drake
# 7         Mr. Morale & the Big Steppers     Kendrick Lamar
# 8                         Harry's House       Harry Styles
# 9                              Her Loss  Drake y 21 Savage
# 10                                Donda         Kayne West
# 11               Red (Taylor's Version)       Taylor Swift
# 12                             Folklore       Taylor Swift
# 13                 Beerbongs & Bentleys        Post Malone
# 14             EL ÚLTIMO TOUR DEL MUNDO          Bad Bunny
# 15                                   Al                 Al
#
#    Reproducciones (en millones)     Fecha de lanzamiento    Ref.
# 0                         184.7    21 de octubre de 2022     NaN
# 1                         154.9  3 de septiembre de 2021  [109]​
# 2                         145.9    13 de octubre de 2023     NaN
# 3                         145.8        6 de mayo de 2022     NaN
# 4                         132.4      29 de junio de 2018  [110]​
# 5                         124.0       7 de julio de 2023     NaN
# 6                         109.0     6 de octubre de 2023     NaN
# 7                          99.9       13 de mayo de 2022     NaN
# 8                          97.6       20 de mayo de 2022     NaN
# 9                          97.3   4 de noviembre de 2022     NaN
# 10                         94.4     29 de agosto de 2021     NaN
# 11                         90.5  12 de noviembre de 2021     NaN
# 12                         79.4      24 de julio de 2020     NaN
# 13                         78.7      27 de abril de 2018  [111]​
# 14                         74.9  27 de noviembre de 2020     NaN
# 15                           Al                       Al      Al

# %%
plt.xticks(rotation=60)
plt.bar(tablas[13]['Artista'],tablas[13]['Reproducciones (en millones)'])
# Out:
# <BarContainer object of 16 artists>

# %% [markdown]
# Ejemplo 3: Hacer un diagrama de barras del Potencial de calentamiento global (PCA) para un tiempo de 20 años para los gases:
#
# Dióxido de carbono
#
# Metano
#
# Óxido nitroso
#
# Diclorodifluorometano
#
# Clorodifluorometano
#
# Tetrafluorometano
#
# Hexafluoretano
#
# Hexafluoruro de azufre
#
# Trifluoruro de nitrógeno

# %%
url = "https://es.wikipedia.org/wiki/Gas_de_efecto_invernadero"
tabla = pd.read_html(url)

# %%
tabla[0]
# Out:
#                                            Compuesto  \
# 0                              Vapor de agua y nubes
# 1                                 Dióxido de carbono
# 2                                             Metano
# 3                                              Ozono
# 4  (A) El vapor de agua varía mucho localmente (B...
#
#                                              Fórmula  \
# 0                                               H 2O
# 1                                                CO2
# 2                                               CH 4
# 3                                                O 3
# 4  (A) El vapor de agua varía mucho localmente (B...
#
#                  Concentración en la atmósfera (ppm)  \
# 0                                       10–50 000(A)
# 1                                               ~400
# 2                                               ~1.8
# 3                                             2–8(B)
# 4  (A) El vapor de agua varía mucho localmente (B...
#
#                                     Contribución (%)
# 0                                             36–72%
# 1                                              9–26%
# 2                                               4–9%
# 3                                               3–7%
# 4  (A) El vapor de agua varía mucho localmente (B...

# %%
tabla[1]
# Out:
#              Nombre del gas Fórmula química Años de vida  \
#              Nombre del gas Fórmula química Años de vida
# 0        Dióxido de carbono             CO2        30–95
# 1                    Metano             CH4           12
# 2             Óxido nitroso             N2O          121
# 3     Diclorodifluorometano          CCl2F2          100
# 4       Clorodifluorometano          CHClF2           12
# 5         Tetrafluorometano             CF4       50 000
# 6            Hexafluoretano            C2F6       10 000
# 7    Hexafluoruro de azufre             SF6        3 200
# 8  Trifluoruro de nitrógeno             NF3          500
#
#   Potencial de calentamiento global (PCA) para un tiempo determinado           \
#                                                              20 años 100 años
# 0                                                  1                        1
# 1                                                 84                       28
# 2                                                264                      265
# 3                                             10 800                   10 200
# 4                                              5 280                    1 760
# 5                                              4 880                    6 630
# 6                                              8 210                   11 100
# 7                                             17 500                   23 500
# 8                                             12 800                   16 100
#
#
#   500 años
# 0        1
# 1      7.6
# 2      153
# 3    5 200
# 4      549
# 5   11 200
# 6   18 200
# 7   32 600
# 8   20 700

# %%
tabla[1]["Nombre del gas"]
# Out:
#              Nombre del gas
# 0        Dióxido de carbono
# 1                    Metano
# 2             Óxido nitroso
# 3     Diclorodifluorometano
# 4       Clorodifluorometano
# 5         Tetrafluorometano
# 6            Hexafluoretano
# 7    Hexafluoruro de azufre
# 8  Trifluoruro de nitrógeno

# %%
tabla[1]["Fórmula química"]
# Out:
#   Fórmula química
# 0             CO2
# 1             CH4
# 2             N2O
# 3          CCl2F2
# 4          CHClF2
# 5             CF4
# 6            C2F6
# 7             SF6
# 8             NF3

# %%
tabla[1]["Potencial de calentamiento global (PCA) para un tiempo determinado"]
# Out:
#   20 años 100 años 500 años
# 0       1        1        1
# 1      84       28      7.6
# 2     264      265      153
# 3  10 800   10 200    5 200
# 4   5 280    1 760      549
# 5   4 880    6 630   11 200
# 6   8 210   11 100   18 200
# 7  17 500   23 500   32 600
# 8  12 800   16 100   20 700

# %%
tabla[1]["Potencial de calentamiento global (PCA) para un tiempo determinado"]["20 años"]
# Out:
# 0         1
# 1        84
# 2       264
# 3    10 800
# 4     5 280
# 5     4 880
# 6     8 210
# 7    17 500
# 8    12 800
# Name: 20 años, dtype: object

# %%
y = pd.DataFrame([[1,84,264,10800,5280,4880,8210,17500,12800]])
y = y.transpose()
y
# Out:
#        0
# 0      1
# 1     84
# 2    264
# 3  10800
# 4   5280
# 5   4880
# 6   8210
# 7  17500
# 8  12800

# %%
FormulaQuimica = ["CO2","CH4","N2O","CCl2F2","CHClF2","CF4","C2F6","SF6","NF3"]
PCA = [1,84,264,10800,5280,4880,8210,17500,12800]

plt.bar(FormulaQuimica,PCA)
plt.show()

# %% [markdown]
# Ejemplo 4: Representar la composición química usando un diagrama circular para:
#
# compuestos = ['carbono','hidrogeno','oxigeno','nitrogeno']
#
# numero = [3,14,2,1]

# %%
compuestos = ['carbono','hidrogeno','oxigeno','nitrogeno']
numero = [3,14,2,1]

plt.pie(numero, labels = compuestos);

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')


# make data
x = [1, 2, 3, 4]
colors = plt.get_cmap('Blues')(np.linspace(0.2, 0.7, len(x)))

# plot
fig, ax = plt.subplots()
ax.pie(x, colors=colors, radius=3, center=(4, 4),
       wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
np.random.seed(10)
D = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))

# plot
fig, ax = plt.subplots()
VP = ax.boxplot(D, positions=[2, 4, 6], widths=1.5, patch_artist=True,
                showmeans=False, showfliers=False,
                medianprops={"color": "white", "linewidth": 0.5},
                boxprops={"facecolor": "C0", "edgecolor": "white",
                          "linewidth": 0.5},
                whiskerprops={"color": "C0", "linewidth": 1.5},
                capprops={"color": "C0", "linewidth": 1.5})

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
np.random.seed(10)
D = np.random.normal((3, 5, 4), (0.75, 1.00, 0.75), (200, 3))

# plot:
fig, ax = plt.subplots()

vp = ax.violinplot(D, [2, 4, 6], widths=2,
                   showmeans=False, showmedians=False, showextrema=False)
# styling:
for body in vp['bodies']:
    body.set_alpha(0.9)
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# Ejemplo 4:

# %%
# instalamos:
# %%capture
# !pip install drawdata

# %%
# Importamos
from drawdata import draw_scatter, draw_histogram, draw_line

# seleccionar A y graficar  la distribución
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df = pd.read_csv("data.csv")
df
# Out:
#               x           y  z
# 0    -11.564335  429.443613  d
# 1     22.814222  398.230434  d
# 2      8.044861  406.463208  d
# 3     20.383712  441.425983  d
# 4      3.436625  425.802929  d
# ..          ...         ... ..
# 354  717.909665  287.539784  c
# 355  695.808380  250.087828  c
# 356  713.878948  237.980397  c
# 357  671.465755  193.692335  c
# 358  683.078060  307.532332  c
#
# [359 rows x 3 columns]

# %% [markdown]
# medidas de tendencia central

# %%
df["x"].mean()
# Out:
# 402.2119760172903

# %%
df["x"].median()
# Out:
# 328.3727209579007

# %% [markdown]
# medidas de dispersion

# %%
df['x'].quantile([.25, .5, .75])
# Out:
# 0.25    193.715932
# 0.50    438.919730
# 0.75    620.196907
# Name: x, dtype: float64

# %%
df['x'].max() - df['x'].min()
# Out:
# 794.0213467252445

# %%
# desviación estándar
round(df['x'].std(),2)
# Out:
# 232.16

# %%
round(df.describe(),2)
# Out:
#             x       y
# count  359.00  359.00
# mean   402.21  267.54
# std    232.16  146.74
# min    -29.64  -21.06
# 25%    193.72  144.32
# 50%    438.92  256.96
# 75%    620.20  412.23
# max    764.39  537.26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359 entries, 0 to 358
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       359 non-null    float64
#  1   y       359 non-null    float64
#  2   z       359 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 8.5+ KB

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo con 10 filas
data = {'Categoría': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],
        'Valor': [12, 18, 5, 22, 15, 10, 30, 8, 17, 14]}
df = pd.DataFrame(data)

# Crear un gráfico de barras utilizando Seaborn
plt.figure(figsize=(8, 6))  # Ajusta el tamaño de la figura si es necesario
sns.barplot(x='Categoría', y='Valor', data=df)

# Agregar etiquetas y título
plt.xlabel('Categoría--')
plt.ylabel('Valor')
plt.title('Diagrama de Barras')

# Mostrar el gráfico
plt.show()

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df2 = pd.read_csv("data_2.csv")
df2
# Out:
#          x         y  z
# 0    0.000  0.950465  a
# 1    0.025  0.946465  a
# 2    0.050  0.946465  a
# 3    0.075  0.946465  a
# 4    0.100  0.946465  a
# ..     ...       ... ..
# 155  0.875  0.256465  d
# 156  0.900  0.228465  d
# 157  0.925  0.210465  d
# 158  0.950  0.188465  d
# 159  0.975  0.160465  d
#
# [160 rows x 3 columns]

# %% [markdown]
# Actividad: Elaborar dataframes y comparar sus medidas de tendencia central para explicar las gráficas (Ref. Teoría cinética molecular de los gases)

# %% [markdown]
# ![boltz_maxw.PNG](data:image/png;base64,...)

# %%
Ref ='https://openstax.org/books/qu%C3%ADmica-2ed/pages/9-5-la-teoria-cinetico-molecular'
